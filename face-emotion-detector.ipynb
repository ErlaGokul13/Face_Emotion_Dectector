# %% [markdown]
# # 1. Import Libraries

# %%
import os
import keras
import itertools
import numpy as np
import pandas as pd
import seaborn as sn
from collections import Counter
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img

from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications import VGG16, MobileNetV2
from tensorflow.keras.layers import Dense, Flatten, Dropout,BatchNormalization ,Activation, GlobalAveragePooling2D
from tensorflow.keras.layers import GaussianNoise
from tensorflow.keras import regularizers

import keras.backend as K
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.callbacks import ReduceLROnPlateau,ModelCheckpoint,EarlyStopping

from IPython.display import Image, HTML
from tensorflow.keras.utils import plot_model

# %% [markdown]
# # 2. Parameter

# %%
# declare path
train_dir = '../input/fer2013/train/'
test_dir = '../input/fer2013/test/'

# Image size

IMAGE_SIZE = (48,48)
IMAGE_SHAPE = IMAGE_SIZE + (3,)

BS = 64
EPOCHS = 125
ADAM_LEARNING_RATE = 0.0001
PATIENCE =10

classes=['Angry','Disgust','Fear','Happy','Neutral','Sad','Surprise']

# %% [markdown]
# # 3. Prepare data

# %%
# Data augmentation

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   featurewise_center=False,
                                   featurewise_std_normalization=False,
                                   rotation_range=10,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   zoom_range=0.1,
                                   horizontal_flip=True)

test_datagen  = ImageDataGenerator(rescale = 1./255)

# %%
# Load datasat

train_dataset  = train_datagen.flow_from_directory(directory = train_dir,
                                                   target_size = IMAGE_SIZE,
                                                   class_mode = 'categorical',
                                                   batch_size = BS)

test_dataset = test_datagen.flow_from_directory(directory = test_dir,
                                                  target_size = IMAGE_SIZE,
                                                  class_mode = 'categorical',
                                                  shuffle =True,
                                                  batch_size = BS)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# # 4. Explore data

# %%
# Total train/test sample

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_dir, 'train')
test_count = count_exp(test_dir, 'test')

HTML(train_count.append(test_count).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>surprise</th>
#       <th>fear</th>
#       <th>angry</th>
#       <th>neutral</th>
#       <th>sad</th>
#       <th>disgust</th>
#       <th>happy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>3171</td>
#       <td>4097</td>
#       <td>3995</td>
#       <td>4965</td>
#       <td>4830</td>
#       <td>436</td>
#       <td>7215</td>
#     </tr>
#     <tr>
#       <th>test</th>
#       <td>831</td>
#       <td>1024</td>
#       <td>958</td>
#       <td>1233</td>
#       <td>1247</td>
#       <td>111</td>
#       <td>1774</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Data labels

class_labels = test_dataset.class_indices
class_labels
# Out:
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
# See the shape of any data

train_sample=next(train_dataset)
print(train_sample[0].shape)
# Out:
# (64, 48, 48, 3)

# %%
# # lot distribution of train/test dataste per class

x = list(test_count.columns)
y1 =train_count.iloc[0].to_list()
y2 = test_count.iloc[0].to_list()
plt.figure(figsize=(12,7))

plt.bar(x, y1, color='blue')
plt.bar(x, y2, bottom=y1, color='violet')
plt.xlabel("Emotions")
plt.ylabel("Train & Test data")
plt.legend(["Train", "Test"], loc='upper left')
plt.title("FER-2013")
plt.savefig('distribution.png')
plt.show()

# %%
# Plot image of each class

plt.figure(figsize=(14,22))
i = 1
for expression in os.listdir(train_dir):
    img = load_img((train_dir + expression +'/'+ os.listdir(train_dir + expression)[1]))
    plt.subplot(1,7,i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %% [markdown]
# # 5. Model

# %%
# Mobinet

base_model = tf.keras.applications.MobileNet(input_shape=IMAGE_SHAPE, include_top=False, weights='imagenet')
base_model.summary()
# Out:
# Model: "mobilenet_1.00_224"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 48, 48, 3)]       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 24, 24, 32)        864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 24, 24, 32)        128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 24, 24, 32)        0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 24, 24, 32)        288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 24, 24, 32)        128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 24, 24, 32)        0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 24, 24, 64)        2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 24, 24, 64)        256
# _________________________________________________________________
# conv_pw_1_relu (ReLU)        (None, 24, 24, 64)        0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 25, 25, 64)        0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 12, 12, 64)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 12, 12, 64)        256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 12, 12, 64)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 12, 12, 128)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 12, 12, 128)       512
# _________________________________________________________________
# conv_pw_2_relu (ReLU)        (None, 12, 12, 128)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 12, 12, 128)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 12, 12, 128)       512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 12, 12, 128)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 12, 12, 128)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 12, 12, 128)       512
# _________________________________________________________________
# conv_pw_3_relu (ReLU)        (None, 12, 12, 128)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 13, 13, 128)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 6, 6, 128)         1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 6, 6, 128)         512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 6, 6, 128)         0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 6, 6, 256)         32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 6, 6, 256)         1024
# _________________________________________________________________
# conv_pw_4_relu (ReLU)        (None, 6, 6, 256)         0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 6, 6, 256)         2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 6, 6, 256)         1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 6, 6, 256)         0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 6, 6, 256)         65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 6, 6, 256)         1024
# _________________________________________________________________
# conv_pw_5_relu (ReLU)        (None, 6, 6, 256)         0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 7, 7, 256)         0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 3, 3, 256)         2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 3, 3, 256)         1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 3, 3, 256)         0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 3, 3, 512)         131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_pw_6_relu (ReLU)        (None, 3, 3, 512)         0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 3, 3, 512)         4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 3, 3, 512)         0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 3, 3, 512)         262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_pw_7_relu (ReLU)        (None, 3, 3, 512)         0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 3, 3, 512)         4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 3, 3, 512)         0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 3, 3, 512)         262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_pw_8_relu (ReLU)        (None, 3, 3, 512)         0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 3, 3, 512)         4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 3, 3, 512)         0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 3, 3, 512)         262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_pw_9_relu (ReLU)        (None, 3, 3, 512)         0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 3, 3, 512)         4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 3, 3, 512)         0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 3, 3, 512)         262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_pw_10_relu (ReLU)       (None, 3, 3, 512)         0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 3, 3, 512)         4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 3, 3, 512)         0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 3, 3, 512)         262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv_pw_11_relu (ReLU)       (None, 3, 3, 512)         0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 1, 1, 512)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 1, 1, 512)         2048
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 1, 1, 512)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 1, 1, 1024)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 1, 1, 1024)        4096
# _________________________________________________________________
# conv_pw_12_relu (ReLU)       (None, 1, 1, 1024)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 1, 1, 1024)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 1, 1, 1024)        4096
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 1, 1, 1024)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 1, 1, 1024)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 1, 1, 1024)        4096
# _________________________________________________________________
# conv_pw_13_relu (ReLU)       (None, 1, 1, 1024)        0
# =================================================================
# Total params: 3,228,864
# Trainable params: 3,206,976
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
# Freezing Layers

for layer in base_model.layers[:-9]:
    layer.trainable=False

# %%
print("Model trainable",len(base_model.layers))
# Out:
# Model trainable 86

# %%
print("Model trainable",len(base_model.trainable_variables))
# Out:
# Model trainable 9

# %%
# Model trainable

print("Model trainable",len(base_model.trainable_variables))
# Out:
# Model trainable 9

# %%
# Build transfer learning Model

model=Sequential()
model.add(base_model)
model.add(GlobalAveragePooling2D())

model.add(Flatten())
model.add(Dense(256, activation='relu',kernel_regularizer=regularizers.l2(0.001),bias_regularizer=regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.3))

model.add(Dense(128, activation='relu',kernel_regularizer=regularizers.l2(0.001),bias_regularizer=regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.3))

model.add(Dense(7, activation="softmax"))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenet_1.00_224 (Function (None, 1, 1, 1024)        3228864
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1024)              0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               262400
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 903
# =================================================================
# Total params: 3,526,599
# Trainable params: 1,885,191
# Non-trainable params: 1,641,408
# _________________________________________________________________

# %%
# Compile model

def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      f1_score,
]

adam = tf.keras.optimizers.Adam(learning_rate=ADAM_LEARNING_RATE, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

model.compile(optimizer=adam, loss='categorical_crossentropy',metrics=METRICS)

# %%
# Run Model

counter = Counter(train_dataset.classes)                          
max_val = float(max(counter.values()))       
class_weights = {class_id : round(max_val/num_images,2) for class_id, num_images in counter.items()}  

lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = PATIENCE,verbose = 1,factor = 0.50, min_lr = 1e-10)
mcp = ModelCheckpoint('model.h5')
es = EarlyStopping(verbose=1, patience=20)

history=model.fit(train_dataset,
                  validation_data=test_dataset,
                  epochs = EPOCHS,
                  verbose =1,
                  callbacks = [lrd,mcp,es], 
                  class_weight = class_weights)
# Out:
# Epoch 1/125
# 449/449 [==============================] - 67s 144ms/step - loss: 4.8662 - accuracy: 0.8244 - precision: 0.2203 - recall: 0.0902 - auc: 0.5713 - f1_score: 0.1278 - val_loss: 2.5110 - val_accuracy: 0.8500 - val_precision: 0.4125 - val_recall: 0.1172 - val_auc: 0.6608 - val_f1_score: 0.1813
# Epoch 2/125
# 449/449 [==============================] - 61s 136ms/step - loss: 4.2694 - accuracy: 0.8390 - precision: 0.3168 - recall: 0.1097 - auc: 0.6283 - f1_score: 0.1625 - val_loss: 2.4053 - val_accuracy: 0.8544 - val_precision: 0.4732 - val_recall: 0.1684 - val_auc: 0.7088 - val_f1_score: 0.2463
# Epoch 3/125
# 449/449 [==============================] - 63s 141ms/step - loss: 4.0543 - accuracy: 0.8436 - precision: 0.3531 - recall: 0.1140 - auc: 0.6530 - f1_score: 0.1718 - val_loss: 2.3398 - val_accuracy: 0.8572 - val_precision: 0.5002 - val_recall: 0.1640 - val_auc: 0.7216 - val_f1_score: 0.2436
# Epoch 4/125
# 449/449 [==============================] - 62s 139ms/step - loss: 3.8736 - accuracy: 0.8479 - precision: 0.3930 - recall: 0.1184 - auc: 0.6733 - f1_score: 0.1812 - val_loss: 2.2989 - val_accuracy: 0.8574 - val_precision: 0.5034 - val_recall: 0.1544 - val_auc: 0.7294 - val_f1_score: 0.2327
# Epoch 5/125
# 449/449 [==============================] - 62s 139ms/step - loss: 3.7774 - accuracy: 0.8511 - precision: 0.4266 - recall: 0.1226 - auc: 0.6852 - f1_score: 0.1895 - val_loss: 2.2716 - val_accuracy: 0.8583 - val_precision: 0.5126 - val_recall: 0.1591 - val_auc: 0.7368 - val_f1_score: 0.2436
# Epoch 6/125
# 449/449 [==============================] - 63s 141ms/step - loss: 3.6892 - accuracy: 0.8543 - precision: 0.4637 - recall: 0.1286 - auc: 0.6996 - f1_score: 0.2004 - val_loss: 2.2005 - val_accuracy: 0.8615 - val_precision: 0.5493 - val_recall: 0.1701 - val_auc: 0.7555 - val_f1_score: 0.2576
# Epoch 7/125
# 449/449 [==============================] - 63s 139ms/step - loss: 3.5774 - accuracy: 0.8556 - precision: 0.4809 - recall: 0.1362 - auc: 0.7121 - f1_score: 0.2115 - val_loss: 2.2255 - val_accuracy: 0.8598 - val_precision: 0.5310 - val_recall: 0.1609 - val_auc: 0.7459 - val_f1_score: 0.2463
# Epoch 8/125
# 449/449 [==============================] - 61s 135ms/step - loss: 3.5306 - accuracy: 0.8569 - precision: 0.4974 - recall: 0.1411 - auc: 0.7194 - f1_score: 0.2188 - val_loss: 2.1354 - val_accuracy: 0.8661 - val_precision: 0.5999 - val_recall: 0.1882 - val_auc: 0.7730 - val_f1_score: 0.2848
# Epoch 9/125
# 449/449 [==============================] - 61s 135ms/step - loss: 3.4537 - accuracy: 0.8589 - precision: 0.5220 - recall: 0.1482 - auc: 0.7304 - f1_score: 0.2300 - val_loss: 2.2460 - val_accuracy: 0.8552 - val_precision: 0.4792 - val_recall: 0.1590 - val_auc: 0.7429 - val_f1_score: 0.2363
# Epoch 10/125
# 449/449 [==============================] - 61s 136ms/step - loss: 3.3754 - accuracy: 0.8589 - precision: 0.5211 - recall: 0.1501 - auc: 0.7401 - f1_score: 0.2321 - val_loss: 2.0718 - val_accuracy: 0.8697 - val_precision: 0.6366 - val_recall: 0.2048 - val_auc: 0.7871 - val_f1_score: 0.3075
# Epoch 11/125
# 449/449 [==============================] - 61s 136ms/step - loss: 3.3471 - accuracy: 0.8608 - precision: 0.5453 - recall: 0.1561 - auc: 0.7463 - f1_score: 0.2414 - val_loss: 2.0408 - val_accuracy: 0.8702 - val_precision: 0.6418 - val_recall: 0.2065 - val_auc: 0.7957 - val_f1_score: 0.3092
# Epoch 12/125
# 449/449 [==============================] - 61s 135ms/step - loss: 3.3175 - accuracy: 0.8609 - precision: 0.5472 - recall: 0.1539 - auc: 0.7490 - f1_score: 0.2395 - val_loss: 2.1030 - val_accuracy: 0.8635 - val_precision: 0.5666 - val_recall: 0.1890 - val_auc: 0.7768 - val_f1_score: 0.2807
# Epoch 13/125
# 449/449 [==============================] - 60s 134ms/step - loss: 3.2653 - accuracy: 0.8627 - precision: 0.5670 - recall: 0.1635 - auc: 0.7590 - f1_score: 0.2530 - val_loss: 2.0193 - val_accuracy: 0.8700 - val_precision: 0.6464 - val_recall: 0.1987 - val_auc: 0.7982 - val_f1_score: 0.3038
# Epoch 14/125
# 449/449 [==============================] - 61s 136ms/step - loss: 3.2268 - accuracy: 0.8632 - precision: 0.5746 - recall: 0.1645 - auc: 0.7638 - f1_score: 0.2548 - val_loss: 2.0099 - val_accuracy: 0.8696 - val_precision: 0.6335 - val_recall: 0.2073 - val_auc: 0.7989 - val_f1_score: 0.3088
# Epoch 15/125
# 449/449 [==============================] - 61s 136ms/step - loss: 3.1658 - accuracy: 0.8632 - precision: 0.5730 - recall: 0.1660 - auc: 0.7691 - f1_score: 0.2564 - val_loss: 1.9770 - val_accuracy: 0.8725 - val_precision: 0.6826 - val_recall: 0.2005 - val_auc: 0.8061 - val_f1_score: 0.3069
# Epoch 16/125
# 449/449 [==============================] - 62s 137ms/step - loss: 3.1323 - accuracy: 0.8646 - precision: 0.5883 - recall: 0.1733 - auc: 0.7764 - f1_score: 0.2667 - val_loss: 1.9618 - val_accuracy: 0.8726 - val_precision: 0.6510 - val_recall: 0.2336 - val_auc: 0.8107 - val_f1_score: 0.3418
# Epoch 17/125
# 449/449 [==============================] - 61s 135ms/step - loss: 3.1106 - accuracy: 0.8652 - precision: 0.5958 - recall: 0.1751 - auc: 0.7789 - f1_score: 0.2695 - val_loss: 1.9930 - val_accuracy: 0.8687 - val_precision: 0.6308 - val_recall: 0.1955 - val_auc: 0.7977 - val_f1_score: 0.2968
# Epoch 18/125
# 449/449 [==============================] - 60s 134ms/step - loss: 3.0669 - accuracy: 0.8660 - precision: 0.6060 - recall: 0.1777 - auc: 0.7822 - f1_score: 0.2739 - val_loss: 1.9850 - val_accuracy: 0.8686 - val_precision: 0.6131 - val_recall: 0.2183 - val_auc: 0.8000 - val_f1_score: 0.3186
# Epoch 19/125
# 449/449 [==============================] - 61s 135ms/step - loss: 3.0253 - accuracy: 0.8669 - precision: 0.6119 - recall: 0.1865 - auc: 0.7881 - f1_score: 0.2849 - val_loss: 2.0911 - val_accuracy: 0.8600 - val_precision: 0.5279 - val_recall: 0.1909 - val_auc: 0.7736 - val_f1_score: 0.2774
# Epoch 20/125
# 449/449 [==============================] - 61s 136ms/step - loss: 3.0081 - accuracy: 0.8670 - precision: 0.6106 - recall: 0.1896 - auc: 0.7915 - f1_score: 0.2881 - val_loss: 1.9369 - val_accuracy: 0.8710 - val_precision: 0.6547 - val_recall: 0.2055 - val_auc: 0.8087 - val_f1_score: 0.3103
# Epoch 21/125
# 449/449 [==============================] - 61s 136ms/step - loss: 2.9530 - accuracy: 0.8680 - precision: 0.6215 - recall: 0.1948 - auc: 0.7969 - f1_score: 0.2956 - val_loss: 1.9307 - val_accuracy: 0.8700 - val_precision: 0.6354 - val_recall: 0.2115 - val_auc: 0.8094 - val_f1_score: 0.3162
# Epoch 22/125
# 449/449 [==============================] - 60s 135ms/step - loss: 2.9310 - accuracy: 0.8682 - precision: 0.6233 - recall: 0.1958 - auc: 0.7992 - f1_score: 0.2972 - val_loss: 1.9173 - val_accuracy: 0.8702 - val_precision: 0.6388 - val_recall: 0.2099 - val_auc: 0.8106 - val_f1_score: 0.3140
# Epoch 23/125
# 449/449 [==============================] - 62s 138ms/step - loss: 2.9249 - accuracy: 0.8678 - precision: 0.6179 - recall: 0.1963 - auc: 0.7992 - f1_score: 0.2970 - val_loss: 1.8819 - val_accuracy: 0.8734 - val_precision: 0.6763 - val_recall: 0.2186 - val_auc: 0.8177 - val_f1_score: 0.3301
# Epoch 24/125
# 449/449 [==============================] - 61s 135ms/step - loss: 2.8858 - accuracy: 0.8691 - precision: 0.6322 - recall: 0.1995 - auc: 0.8037 - f1_score: 0.3023 - val_loss: 1.8724 - val_accuracy: 0.8728 - val_precision: 0.6589 - val_recall: 0.2274 - val_auc: 0.8186 - val_f1_score: 0.3337
# Epoch 25/125
# 449/449 [==============================] - 62s 137ms/step - loss: 2.8581 - accuracy: 0.8699 - precision: 0.6389 - recall: 0.2058 - auc: 0.8078 - f1_score: 0.3103 - val_loss: 1.8362 - val_accuracy: 0.8752 - val_precision: 0.6796 - val_recall: 0.2388 - val_auc: 0.8256 - val_f1_score: 0.3515
# Epoch 26/125
# 449/449 [==============================] - 60s 135ms/step - loss: 2.8423 - accuracy: 0.8703 - precision: 0.6419 - recall: 0.2080 - auc: 0.8098 - f1_score: 0.3132 - val_loss: 1.8253 - val_accuracy: 0.8742 - val_precision: 0.6673 - val_recall: 0.2386 - val_auc: 0.8268 - val_f1_score: 0.3500
# Epoch 27/125
# 449/449 [==============================] - 63s 140ms/step - loss: 2.8183 - accuracy: 0.8707 - precision: 0.6447 - recall: 0.2112 - auc: 0.8127 - f1_score: 0.3169 - val_loss: 1.8322 - val_accuracy: 0.8739 - val_precision: 0.6590 - val_recall: 0.2434 - val_auc: 0.8234 - val_f1_score: 0.3532
# Epoch 28/125
# 449/449 [==============================] - 60s 134ms/step - loss: 2.7772 - accuracy: 0.8711 - precision: 0.6432 - recall: 0.2197 - auc: 0.8163 - f1_score: 0.3262 - val_loss: 1.8174 - val_accuracy: 0.8751 - val_precision: 0.6596 - val_recall: 0.2600 - val_auc: 0.8256 - val_f1_score: 0.3715
# Epoch 29/125
# 449/449 [==============================] - 60s 134ms/step - loss: 2.7541 - accuracy: 0.8720 - precision: 0.6489 - recall: 0.2265 - auc: 0.8184 - f1_score: 0.3347 - val_loss: 1.7977 - val_accuracy: 0.8753 - val_precision: 0.6619 - val_recall: 0.2597 - val_auc: 0.8284 - val_f1_score: 0.3714
# Epoch 30/125
# 449/449 [==============================] - 60s 133ms/step - loss: 2.7208 - accuracy: 0.8721 - precision: 0.6496 - recall: 0.2268 - auc: 0.8206 - f1_score: 0.3351 - val_loss: 1.8810 - val_accuracy: 0.8690 - val_precision: 0.6040 - val_recall: 0.2407 - val_auc: 0.8087 - val_f1_score: 0.3449
# Epoch 31/125
# 449/449 [==============================] - 61s 136ms/step - loss: 2.6942 - accuracy: 0.8729 - precision: 0.6580 - recall: 0.2302 - auc: 0.8217 - f1_score: 0.3400 - val_loss: 1.7751 - val_accuracy: 0.8752 - val_precision: 0.6648 - val_recall: 0.2548 - val_auc: 0.8308 - val_f1_score: 0.3662
# Epoch 32/125
# 449/449 [==============================] - 60s 133ms/step - loss: 2.6620 - accuracy: 0.8742 - precision: 0.6674 - recall: 0.2383 - auc: 0.8272 - f1_score: 0.3501 - val_loss: 1.8176 - val_accuracy: 0.8711 - val_precision: 0.6272 - val_recall: 0.2400 - val_auc: 0.8203 - val_f1_score: 0.3442
# Epoch 33/125
# 449/449 [==============================] - 60s 133ms/step - loss: 2.6445 - accuracy: 0.8744 - precision: 0.6672 - recall: 0.2411 - auc: 0.8286 - f1_score: 0.3532 - val_loss: 1.7779 - val_accuracy: 0.8740 - val_precision: 0.6564 - val_recall: 0.2470 - val_auc: 0.8269 - val_f1_score: 0.3571
# Epoch 34/125
# 449/449 [==============================] - 60s 134ms/step - loss: 2.6528 - accuracy: 0.8740 - precision: 0.6592 - recall: 0.2450 - auc: 0.8278 - f1_score: 0.3562 - val_loss: 1.7252 - val_accuracy: 0.8764 - val_precision: 0.6715 - val_recall: 0.2646 - val_auc: 0.8381 - val_f1_score: 0.3792
# Epoch 35/125
# 449/449 [==============================] - 63s 140ms/step - loss: 2.6026 - accuracy: 0.8747 - precision: 0.6696 - recall: 0.2429 - auc: 0.8321 - f1_score: 0.3554 - val_loss: 1.7382 - val_accuracy: 0.8758 - val_precision: 0.6775 - val_recall: 0.2494 - val_auc: 0.8330 - val_f1_score: 0.3593
# Epoch 36/125
# 449/449 [==============================] - 61s 135ms/step - loss: 2.6007 - accuracy: 0.8753 - precision: 0.6705 - recall: 0.2503 - auc: 0.8330 - f1_score: 0.3633 - val_loss: 1.7925 - val_accuracy: 0.8704 - val_precision: 0.6216 - val_recall: 0.2375 - val_auc: 0.8198 - val_f1_score: 0.3426
# Epoch 37/125
# 449/449 [==============================] - 62s 137ms/step - loss: 2.5934 - accuracy: 0.8748 - precision: 0.6613 - recall: 0.2526 - auc: 0.8335 - f1_score: 0.3645 - val_loss: 1.7359 - val_accuracy: 0.8737 - val_precision: 0.6511 - val_recall: 0.2498 - val_auc: 0.8305 - val_f1_score: 0.3596
# Epoch 38/125
# 449/449 [==============================] - 62s 139ms/step - loss: 2.5687 - accuracy: 0.8748 - precision: 0.6651 - recall: 0.2492 - auc: 0.8356 - f1_score: 0.3614 - val_loss: 1.7107 - val_accuracy: 0.8755 - val_precision: 0.6637 - val_recall: 0.2601 - val_auc: 0.8348 - val_f1_score: 0.3730
# Epoch 39/125
# 449/449 [==============================] - 66s 148ms/step - loss: 2.5409 - accuracy: 0.8762 - precision: 0.6714 - recall: 0.2615 - auc: 0.8380 - f1_score: 0.3750 - val_loss: 1.7119 - val_accuracy: 0.8754 - val_precision: 0.6469 - val_recall: 0.2816 - val_auc: 0.8345 - val_f1_score: 0.3887
# Epoch 40/125
# 449/449 [==============================] - 65s 144ms/step - loss: 2.5446 - accuracy: 0.8761 - precision: 0.6704 - recall: 0.2610 - auc: 0.8380 - f1_score: 0.3748 - val_loss: 1.7042 - val_accuracy: 0.8758 - val_precision: 0.6564 - val_recall: 0.2739 - val_auc: 0.8345 - val_f1_score: 0.3858
# Epoch 41/125
# 449/449 [==============================] - 60s 134ms/step - loss: 2.4912 - accuracy: 0.8769 - precision: 0.6777 - recall: 0.2642 - auc: 0.8423 - f1_score: 0.3789 - val_loss: 1.6850 - val_accuracy: 0.8769 - val_precision: 0.6677 - val_recall: 0.2749 - val_auc: 0.8374 - val_f1_score: 0.3853
# Epoch 42/125
# 449/449 [==============================] - 61s 136ms/step - loss: 2.4841 - accuracy: 0.8777 - precision: 0.6826 - recall: 0.2692 - auc: 0.8426 - f1_score: 0.3847 - val_loss: 1.7021 - val_accuracy: 0.8749 - val_precision: 0.6557 - val_recall: 0.2611 - val_auc: 0.8320 - val_f1_score: 0.3737
# Epoch 43/125
# 449/449 [==============================] - 61s 135ms/step - loss: 2.4694 - accuracy: 0.8777 - precision: 0.6773 - recall: 0.2754 - auc: 0.8444 - f1_score: 0.3905 - val_loss: 1.7038 - val_accuracy: 0.8746 - val_precision: 0.6376 - val_recall: 0.2831 - val_auc: 0.8311 - val_f1_score: 0.3887
# Epoch 44/125
# 449/449 [==============================] - 61s 135ms/step - loss: 2.4537 - accuracy: 0.8782 - precision: 0.6801 - recall: 0.2782 - auc: 0.8455 - f1_score: 0.3934 - val_loss: 1.6243 - val_accuracy: 0.8789 - val_precision: 0.6866 - val_recall: 0.2802 - val_auc: 0.8473 - val_f1_score: 0.3960
# Epoch 45/125
# 449/449 [==============================] - 61s 136ms/step - loss: 2.4205 - accuracy: 0.8790 - precision: 0.6866 - recall: 0.2815 - auc: 0.8478 - f1_score: 0.3983 - val_loss: 1.6566 - val_accuracy: 0.8767 - val_precision: 0.6541 - val_recall: 0.2906 - val_auc: 0.8392 - val_f1_score: 0.4002
# Epoch 46/125
# 449/449 [==============================] - 61s 136ms/step - loss: 2.4128 - accuracy: 0.8788 - precision: 0.6818 - recall: 0.2849 - auc: 0.8496 - f1_score: 0.4007 - val_loss: 1.6328 - val_accuracy: 0.8783 - val_precision: 0.6564 - val_recall: 0.3111 - val_auc: 0.8442 - val_f1_score: 0.4213
# Epoch 47/125
# 449/449 [==============================] - 63s 140ms/step - loss: 2.4045 - accuracy: 0.8791 - precision: 0.6821 - recall: 0.2877 - auc: 0.8502 - f1_score: 0.4034 - val_loss: 1.7296 - val_accuracy: 0.8705 - val_precision: 0.6010 - val_recall: 0.2786 - val_auc: 0.8233 - val_f1_score: 0.3809
# Epoch 48/125
# 449/449 [==============================] - 60s 135ms/step - loss: 2.3907 - accuracy: 0.8800 - precision: 0.6870 - recall: 0.2945 - auc: 0.8506 - f1_score: 0.4111 - val_loss: 1.6535 - val_accuracy: 0.8751 - val_precision: 0.6336 - val_recall: 0.2983 - val_auc: 0.8385 - val_f1_score: 0.4066
# Epoch 49/125
# 449/449 [==============================] - 60s 133ms/step - loss: 2.3651 - accuracy: 0.8808 - precision: 0.6939 - recall: 0.2963 - auc: 0.8546 - f1_score: 0.4142 - val_loss: 1.6066 - val_accuracy: 0.8778 - val_precision: 0.6621 - val_recall: 0.2948 - val_auc: 0.8463 - val_f1_score: 0.4062
# Epoch 50/125
# 449/449 [==============================] - 61s 135ms/step - loss: 2.3429 - accuracy: 0.8803 - precision: 0.6844 - recall: 0.3007 - auc: 0.8548 - f1_score: 0.4166 - val_loss: 1.6786 - val_accuracy: 0.8736 - val_precision: 0.6197 - val_recall: 0.2986 - val_auc: 0.8313 - val_f1_score: 0.4005
# Epoch 51/125
# 449/449 [==============================] - 60s 133ms/step - loss: 2.3360 - accuracy: 0.8808 - precision: 0.6875 - recall: 0.3041 - auc: 0.8566 - f1_score: 0.4207 - val_loss: 1.5929 - val_accuracy: 0.8788 - val_precision: 0.6683 - val_recall: 0.3009 - val_auc: 0.8471 - val_f1_score: 0.4123
# Epoch 52/125
# 449/449 [==============================] - 60s 134ms/step - loss: 2.3264 - accuracy: 0.8811 - precision: 0.6878 - recall: 0.3073 - auc: 0.8576 - f1_score: 0.4238 - val_loss: 1.6067 - val_accuracy: 0.8781 - val_precision: 0.6587 - val_recall: 0.3050 - val_auc: 0.8434 - val_f1_score: 0.4136
# Epoch 53/125
# 449/449 [==============================] - 59s 132ms/step - loss: 2.2961 - accuracy: 0.8817 - precision: 0.6915 - recall: 0.3108 - auc: 0.8586 - f1_score: 0.4281 - val_loss: 1.5933 - val_accuracy: 0.8776 - val_precision: 0.6531 - val_recall: 0.3058 - val_auc: 0.8459 - val_f1_score: 0.4140
# Epoch 54/125
# 449/449 [==============================] - 61s 137ms/step - loss: 2.3251 - accuracy: 0.8811 - precision: 0.6858 - recall: 0.3095 - auc: 0.8573 - f1_score: 0.4253 - val_loss: 1.6568 - val_accuracy: 0.8738 - val_precision: 0.6241 - val_recall: 0.2924 - val_auc: 0.8322 - val_f1_score: 0.3954
# Epoch 55/125
# 449/449 [==============================] - 64s 142ms/step - loss: 2.2711 - accuracy: 0.8823 - precision: 0.6921 - recall: 0.3171 - auc: 0.8615 - f1_score: 0.4338 - val_loss: 1.6935 - val_accuracy: 0.8713 - val_precision: 0.6013 - val_recall: 0.2941 - val_auc: 0.8265 - val_f1_score: 0.3932
# Epoch 56/125
# 449/449 [==============================] - 62s 138ms/step - loss: 2.2705 - accuracy: 0.8827 - precision: 0.6949 - recall: 0.3194 - auc: 0.8625 - f1_score: 0.4365 - val_loss: 1.5757 - val_accuracy: 0.8789 - val_precision: 0.6503 - val_recall: 0.3288 - val_auc: 0.8479 - val_f1_score: 0.4356
# Epoch 57/125
# 449/449 [==============================] - 59s 132ms/step - loss: 2.2596 - accuracy: 0.8825 - precision: 0.6902 - recall: 0.3221 - auc: 0.8636 - f1_score: 0.4379 - val_loss: 1.5971 - val_accuracy: 0.8768 - val_precision: 0.6447 - val_recall: 0.3072 - val_auc: 0.8418 - val_f1_score: 0.4139
# Epoch 58/125
# 449/449 [==============================] - 60s 134ms/step - loss: 2.2329 - accuracy: 0.8837 - precision: 0.6976 - recall: 0.3275 - auc: 0.8651 - f1_score: 0.4447 - val_loss: 1.5719 - val_accuracy: 0.8782 - val_precision: 0.6448 - val_recall: 0.3285 - val_auc: 0.8475 - val_f1_score: 0.4355
# Epoch 59/125
# 449/449 [==============================] - 60s 134ms/step - loss: 2.2347 - accuracy: 0.8833 - precision: 0.6956 - recall: 0.3252 - auc: 0.8640 - f1_score: 0.4422 - val_loss: 1.6152 - val_accuracy: 0.8753 - val_precision: 0.6309 - val_recall: 0.3059 - val_auc: 0.8362 - val_f1_score: 0.4083
# Epoch 60/125
# 449/449 [==============================] - 60s 134ms/step - loss: 2.2112 - accuracy: 0.8845 - precision: 0.7021 - recall: 0.3328 - auc: 0.8675 - f1_score: 0.4502 - val_loss: 1.5525 - val_accuracy: 0.8790 - val_precision: 0.6567 - val_recall: 0.3200 - val_auc: 0.8491 - val_f1_score: 0.4282
# Epoch 61/125
# 449/449 [==============================] - 61s 135ms/step - loss: 2.2039 - accuracy: 0.8851 - precision: 0.7048 - recall: 0.3366 - auc: 0.8679 - f1_score: 0.4545 - val_loss: 1.5843 - val_accuracy: 0.8775 - val_precision: 0.6419 - val_recall: 0.3221 - val_auc: 0.8427 - val_f1_score: 0.4275
# Epoch 62/125
# 449/449 [==============================] - 60s 133ms/step - loss: 2.1839 - accuracy: 0.8850 - precision: 0.7001 - recall: 0.3416 - auc: 0.8695 - f1_score: 0.4579 - val_loss: 1.6398 - val_accuracy: 0.8736 - val_precision: 0.6079 - val_recall: 0.3245 - val_auc: 0.8326 - val_f1_score: 0.4215
# Epoch 63/125
# 449/449 [==============================] - 61s 135ms/step - loss: 2.1711 - accuracy: 0.8849 - precision: 0.7002 - recall: 0.3392 - auc: 0.8686 - f1_score: 0.4558 - val_loss: 1.5529 - val_accuracy: 0.8778 - val_precision: 0.6429 - val_recall: 0.3260 - val_auc: 0.8478 - val_f1_score: 0.4308
# Epoch 64/125
# 449/449 [==============================] - 60s 133ms/step - loss: 2.1588 - accuracy: 0.8856 - precision: 0.7008 - recall: 0.3479 - auc: 0.8712 - f1_score: 0.4638 - val_loss: 1.5369 - val_accuracy: 0.8786 - val_precision: 0.6443 - val_recall: 0.3351 - val_auc: 0.8505 - val_f1_score: 0.4374
# Epoch 65/125
# 449/449 [==============================] - 60s 134ms/step - loss: 2.1483 - accuracy: 0.8857 - precision: 0.7037 - recall: 0.3450 - auc: 0.8727 - f1_score: 0.4620 - val_loss: 1.5120 - val_accuracy: 0.8807 - val_precision: 0.6612 - val_recall: 0.3380 - val_auc: 0.8546 - val_f1_score: 0.4449
# Epoch 66/125
# 449/449 [==============================] - 60s 133ms/step - loss: 2.1488 - accuracy: 0.8862 - precision: 0.7060 - recall: 0.3487 - auc: 0.8725 - f1_score: 0.4658 - val_loss: 1.5482 - val_accuracy: 0.8773 - val_precision: 0.6381 - val_recall: 0.3267 - val_auc: 0.8469 - val_f1_score: 0.4315
# Epoch 67/125
# 449/449 [==============================] - 66s 147ms/step - loss: 2.1225 - accuracy: 0.8871 - precision: 0.7056 - recall: 0.3600 - auc: 0.8746 - f1_score: 0.4759 - val_loss: 1.5173 - val_accuracy: 0.8799 - val_precision: 0.6511 - val_recall: 0.3429 - val_auc: 0.8526 - val_f1_score: 0.4495
# Epoch 68/125
# 449/449 [==============================] - 63s 141ms/step - loss: 2.1218 - accuracy: 0.8863 - precision: 0.7019 - recall: 0.3549 - auc: 0.8744 - f1_score: 0.4704 - val_loss: 1.5265 - val_accuracy: 0.8786 - val_precision: 0.6395 - val_recall: 0.3435 - val_auc: 0.8509 - val_f1_score: 0.4435
# Epoch 69/125
# 449/449 [==============================] - 60s 134ms/step - loss: 2.0895 - accuracy: 0.8878 - precision: 0.7082 - recall: 0.3649 - auc: 0.8783 - f1_score: 0.4805 - val_loss: 1.5258 - val_accuracy: 0.8791 - val_precision: 0.6434 - val_recall: 0.3444 - val_auc: 0.8500 - val_f1_score: 0.4453
# Epoch 70/125
# 449/449 [==============================] - 63s 139ms/step - loss: 2.0877 - accuracy: 0.8870 - precision: 0.7009 - recall: 0.3648 - auc: 0.8776 - f1_score: 0.4786 - val_loss: 1.5016 - val_accuracy: 0.8804 - val_precision: 0.6526 - val_recall: 0.3483 - val_auc: 0.8544 - val_f1_score: 0.4526
# Epoch 71/125
# 449/449 [==============================] - 63s 140ms/step - loss: 2.0734 - accuracy: 0.8885 - precision: 0.7109 - recall: 0.3700 - auc: 0.8793 - f1_score: 0.4855 - val_loss: 1.4955 - val_accuracy: 0.8811 - val_precision: 0.6513 - val_recall: 0.3610 - val_auc: 0.8563 - val_f1_score: 0.4641
# Epoch 72/125
# 449/449 [==============================] - 63s 140ms/step - loss: 2.0619 - accuracy: 0.8887 - precision: 0.7087 - recall: 0.3746 - auc: 0.8803 - f1_score: 0.4892 - val_loss: 1.5585 - val_accuracy: 0.8765 - val_precision: 0.6209 - val_recall: 0.3480 - val_auc: 0.8438 - val_f1_score: 0.4464
# Epoch 73/125
# 449/449 [==============================] - 62s 137ms/step - loss: 2.0722 - accuracy: 0.8880 - precision: 0.7048 - recall: 0.3716 - auc: 0.8783 - f1_score: 0.4855 - val_loss: 1.5022 - val_accuracy: 0.8803 - val_precision: 0.6570 - val_recall: 0.3390 - val_auc: 0.8523 - val_f1_score: 0.4450
# Epoch 74/125
# 449/449 [==============================] - 62s 138ms/step - loss: 2.0386 - accuracy: 0.8896 - precision: 0.7138 - recall: 0.3798 - auc: 0.8828 - f1_score: 0.4949 - val_loss: 1.5130 - val_accuracy: 0.8785 - val_precision: 0.6349 - val_recall: 0.3511 - val_auc: 0.8514 - val_f1_score: 0.4515
# Epoch 75/125
# 449/449 [==============================] - 62s 138ms/step - loss: 2.0201 - accuracy: 0.8905 - precision: 0.7168 - recall: 0.3860 - auc: 0.8843 - f1_score: 0.5007 - val_loss: 1.4911 - val_accuracy: 0.8812 - val_precision: 0.6479 - val_recall: 0.3696 - val_auc: 0.8558 - val_f1_score: 0.4713
# Epoch 76/125
# 449/449 [==============================] - 64s 142ms/step - loss: 2.0117 - accuracy: 0.8898 - precision: 0.7095 - recall: 0.3870 - auc: 0.8839 - f1_score: 0.4998 - val_loss: 1.4865 - val_accuracy: 0.8806 - val_precision: 0.6432 - val_recall: 0.3682 - val_auc: 0.8562 - val_f1_score: 0.4674
# Epoch 77/125
# 449/449 [==============================] - 61s 137ms/step - loss: 2.0306 - accuracy: 0.8894 - precision: 0.7074 - recall: 0.3847 - auc: 0.8834 - f1_score: 0.4973 - val_loss: 1.5024 - val_accuracy: 0.8791 - val_precision: 0.6346 - val_recall: 0.3619 - val_auc: 0.8526 - val_f1_score: 0.4580
# Epoch 78/125
# 449/449 [==============================] - 60s 133ms/step - loss: 2.0339 - accuracy: 0.8897 - precision: 0.7106 - recall: 0.3846 - auc: 0.8840 - f1_score: 0.4982 - val_loss: 1.4856 - val_accuracy: 0.8804 - val_precision: 0.6400 - val_recall: 0.3727 - val_auc: 0.8564 - val_f1_score: 0.4695
# Epoch 79/125
# 449/449 [==============================] - 59s 131ms/step - loss: 1.9788 - accuracy: 0.8912 - precision: 0.7177 - recall: 0.3930 - auc: 0.8879 - f1_score: 0.5069 - val_loss: 1.4949 - val_accuracy: 0.8791 - val_precision: 0.6311 - val_recall: 0.3695 - val_auc: 0.8540 - val_f1_score: 0.4649
# Epoch 80/125
# 449/449 [==============================] - 60s 134ms/step - loss: 1.9677 - accuracy: 0.8915 - precision: 0.7164 - recall: 0.3979 - auc: 0.8879 - f1_score: 0.5106 - val_loss: 1.5331 - val_accuracy: 0.8751 - val_precision: 0.6154 - val_recall: 0.3353 - val_auc: 0.8444 - val_f1_score: 0.4339
# Epoch 81/125
# 449/449 [==============================] - 63s 140ms/step - loss: 1.9780 - accuracy: 0.8915 - precision: 0.7156 - recall: 0.3987 - auc: 0.8884 - f1_score: 0.5111 - val_loss: 1.4943 - val_accuracy: 0.8787 - val_precision: 0.6326 - val_recall: 0.3600 - val_auc: 0.8527 - val_f1_score: 0.4591
# Epoch 82/125
# 449/449 [==============================] - 59s 132ms/step - loss: 1.9449 - accuracy: 0.8923 - precision: 0.7211 - recall: 0.4015 - auc: 0.8904 - f1_score: 0.5148 - val_loss: 1.4835 - val_accuracy: 0.8800 - val_precision: 0.6357 - val_recall: 0.3749 - val_auc: 0.8554 - val_f1_score: 0.4716
# Epoch 83/125
# 449/449 [==============================] - 58s 130ms/step - loss: 1.9498 - accuracy: 0.8929 - precision: 0.7200 - recall: 0.4092 - auc: 0.8907 - f1_score: 0.5210 - val_loss: 1.5096 - val_accuracy: 0.8768 - val_precision: 0.6220 - val_recall: 0.3515 - val_auc: 0.8493 - val_f1_score: 0.4459
# Epoch 84/125
# 449/449 [==============================] - 59s 131ms/step - loss: 1.9413 - accuracy: 0.8923 - precision: 0.7194 - recall: 0.4035 - auc: 0.8904 - f1_score: 0.5160 - val_loss: 1.5047 - val_accuracy: 0.8766 - val_precision: 0.6210 - val_recall: 0.3500 - val_auc: 0.8499 - val_f1_score: 0.4462
# Epoch 85/125
# 449/449 [==============================] - 61s 137ms/step - loss: 1.9244 - accuracy: 0.8930 - precision: 0.7213 - recall: 0.4095 - auc: 0.8919 - f1_score: 0.5215 - val_loss: 1.5563 - val_accuracy: 0.8726 - val_precision: 0.5924 - val_recall: 0.3465 - val_auc: 0.8404 - val_f1_score: 0.4361
# Epoch 86/125
# 449/449 [==============================] - 59s 132ms/step - loss: 1.9370 - accuracy: 0.8935 - precision: 0.7220 - recall: 0.4135 - auc: 0.8916 - f1_score: 0.5247 - val_loss: 1.5274 - val_accuracy: 0.8777 - val_precision: 0.6199 - val_recall: 0.3714 - val_auc: 0.8478 - val_f1_score: 0.4632
# Epoch 87/125
# 449/449 [==============================] - 58s 130ms/step - loss: 1.9070 - accuracy: 0.8944 - precision: 0.7271 - recall: 0.4179 - auc: 0.8946 - f1_score: 0.5299 - val_loss: 1.4914 - val_accuracy: 0.8776 - val_precision: 0.6194 - val_recall: 0.3707 - val_auc: 0.8534 - val_f1_score: 0.4621
# Epoch 88/125
# 449/449 [==============================] - 61s 135ms/step - loss: 1.9295 - accuracy: 0.8931 - precision: 0.7203 - recall: 0.4113 - auc: 0.8921 - f1_score: 0.5225 - val_loss: 1.5033 - val_accuracy: 0.8778 - val_precision: 0.6195 - val_recall: 0.3753 - val_auc: 0.8511 - val_f1_score: 0.4681
# Epoch 89/125
# 449/449 [==============================] - 61s 135ms/step - loss: 1.8984 - accuracy: 0.8947 - precision: 0.7255 - recall: 0.4226 - auc: 0.8962 - f1_score: 0.5332 - val_loss: 1.4553 - val_accuracy: 0.8818 - val_precision: 0.6419 - val_recall: 0.3908 - val_auc: 0.8597 - val_f1_score: 0.4845
# Epoch 90/125
# 449/449 [==============================] - 63s 140ms/step - loss: 1.8836 - accuracy: 0.8951 - precision: 0.7265 - recall: 0.4263 - auc: 0.8966 - f1_score: 0.5360 - val_loss: 1.5481 - val_accuracy: 0.8749 - val_precision: 0.6004 - val_recall: 0.3717 - val_auc: 0.8434 - val_f1_score: 0.4598
# Epoch 91/125
# 449/449 [==============================] - 60s 135ms/step - loss: 1.8888 - accuracy: 0.8949 - precision: 0.7242 - recall: 0.4271 - auc: 0.8962 - f1_score: 0.5365 - val_loss: 1.4857 - val_accuracy: 0.8786 - val_precision: 0.6240 - val_recall: 0.3780 - val_auc: 0.8534 - val_f1_score: 0.4712
# Epoch 92/125
# 449/449 [==============================] - 60s 133ms/step - loss: 1.8822 - accuracy: 0.8952 - precision: 0.7254 - recall: 0.4290 - auc: 0.8970 - f1_score: 0.5381 - val_loss: 1.4738 - val_accuracy: 0.8792 - val_precision: 0.6267 - val_recall: 0.3821 - val_auc: 0.8564 - val_f1_score: 0.4724
# Epoch 93/125
# 449/449 [==============================] - 59s 132ms/step - loss: 1.8533 - accuracy: 0.8969 - precision: 0.7345 - recall: 0.4360 - auc: 0.8989 - f1_score: 0.5465 - val_loss: 1.4809 - val_accuracy: 0.8777 - val_precision: 0.6206 - val_recall: 0.3703 - val_auc: 0.8538 - val_f1_score: 0.4641
# Epoch 94/125
# 449/449 [==============================] - 59s 131ms/step - loss: 1.8685 - accuracy: 0.8953 - precision: 0.7234 - recall: 0.4324 - auc: 0.8980 - f1_score: 0.5405 - val_loss: 1.5100 - val_accuracy: 0.8780 - val_precision: 0.6187 - val_recall: 0.3805 - val_auc: 0.8486 - val_f1_score: 0.4693
# Epoch 95/125
# 449/449 [==============================] - 62s 139ms/step - loss: 1.8489 - accuracy: 0.8955 - precision: 0.7252 - recall: 0.4323 - auc: 0.8988 - f1_score: 0.5408 - val_loss: 1.4754 - val_accuracy: 0.8793 - val_precision: 0.6245 - val_recall: 0.3897 - val_auc: 0.8555 - val_f1_score: 0.4774
# Epoch 96/125
# 449/449 [==============================] - 63s 141ms/step - loss: 1.8246 - accuracy: 0.8975 - precision: 0.7338 - recall: 0.4430 - auc: 0.9018 - f1_score: 0.5513 - val_loss: 1.5479 - val_accuracy: 0.8734 - val_precision: 0.5900 - val_recall: 0.3729 - val_auc: 0.8420 - val_f1_score: 0.4566
# Epoch 97/125
# 449/449 [==============================] - 63s 140ms/step - loss: 1.8222 - accuracy: 0.8969 - precision: 0.7291 - recall: 0.4432 - auc: 0.9017 - f1_score: 0.5504 - val_loss: 1.4796 - val_accuracy: 0.8788 - val_precision: 0.6197 - val_recall: 0.3918 - val_auc: 0.8543 - val_f1_score: 0.4780
# Epoch 98/125
# 449/449 [==============================] - 71s 159ms/step - loss: 1.8396 - accuracy: 0.8970 - precision: 0.7292 - recall: 0.4433 - auc: 0.9019 - f1_score: 0.5507 - val_loss: 1.5077 - val_accuracy: 0.8763 - val_precision: 0.6086 - val_recall: 0.3755 - val_auc: 0.8483 - val_f1_score: 0.4644
# Epoch 99/125
# 449/449 [==============================] - 64s 143ms/step - loss: 1.8275 - accuracy: 0.8980 - precision: 0.7347 - recall: 0.4481 - auc: 0.9026 - f1_score: 0.5558 - val_loss: 1.5220 - val_accuracy: 0.8744 - val_precision: 0.5976 - val_recall: 0.3695 - val_auc: 0.8456 - val_f1_score: 0.4543
#
# Epoch 00099: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 100/125
# 449/449 [==============================] - 59s 132ms/step - loss: 1.7751 - accuracy: 0.8999 - precision: 0.7406 - recall: 0.4608 - auc: 0.9063 - f1_score: 0.5672 - val_loss: 1.4642 - val_accuracy: 0.8802 - val_precision: 0.6301 - val_recall: 0.3916 - val_auc: 0.8568 - val_f1_score: 0.4835
# Epoch 101/125
# 449/449 [==============================] - 60s 135ms/step - loss: 1.7354 - accuracy: 0.9013 - precision: 0.7466 - recall: 0.4682 - auc: 0.9104 - f1_score: 0.5748 - val_loss: 1.4739 - val_accuracy: 0.8802 - val_precision: 0.6269 - val_recall: 0.3996 - val_auc: 0.8559 - val_f1_score: 0.4873
# Epoch 102/125
# 449/449 [==============================] - 62s 137ms/step - loss: 1.7101 - accuracy: 0.9019 - precision: 0.7472 - recall: 0.4731 - auc: 0.9123 - f1_score: 0.5787 - val_loss: 1.4902 - val_accuracy: 0.8789 - val_precision: 0.6165 - val_recall: 0.4026 - val_auc: 0.8538 - val_f1_score: 0.4856
# Epoch 103/125
# 449/449 [==============================] - 61s 135ms/step - loss: 1.6937 - accuracy: 0.9031 - precision: 0.7488 - recall: 0.4840 - auc: 0.9139 - f1_score: 0.5869 - val_loss: 1.4656 - val_accuracy: 0.8808 - val_precision: 0.6258 - val_recall: 0.4124 - val_auc: 0.8595 - val_f1_score: 0.4967
# Epoch 104/125
# 449/449 [==============================] - 59s 132ms/step - loss: 1.6906 - accuracy: 0.9030 - precision: 0.7477 - recall: 0.4848 - auc: 0.9147 - f1_score: 0.5874 - val_loss: 1.4684 - val_accuracy: 0.8796 - val_precision: 0.6174 - val_recall: 0.4139 - val_auc: 0.8586 - val_f1_score: 0.4945
# Epoch 105/125
# 449/449 [==============================] - 60s 134ms/step - loss: 1.6701 - accuracy: 0.9040 - precision: 0.7505 - recall: 0.4917 - auc: 0.9159 - f1_score: 0.5932 - val_loss: 1.4806 - val_accuracy: 0.8794 - val_precision: 0.6185 - val_recall: 0.4064 - val_auc: 0.8561 - val_f1_score: 0.4891
# Epoch 106/125
# 449/449 [==============================] - 63s 141ms/step - loss: 1.6747 - accuracy: 0.9040 - precision: 0.7510 - recall: 0.4902 - auc: 0.9154 - f1_score: 0.5924 - val_loss: 1.4769 - val_accuracy: 0.8799 - val_precision: 0.6175 - val_recall: 0.4178 - val_auc: 0.8581 - val_f1_score: 0.4944
# Epoch 107/125
# 449/449 [==============================] - 60s 135ms/step - loss: 1.6972 - accuracy: 0.9031 - precision: 0.7447 - recall: 0.4900 - auc: 0.9148 - f1_score: 0.5902 - val_loss: 1.4860 - val_accuracy: 0.8793 - val_precision: 0.6157 - val_recall: 0.4133 - val_auc: 0.8560 - val_f1_score: 0.4921
# Epoch 108/125
# 449/449 [==============================] - 63s 141ms/step - loss: 1.6518 - accuracy: 0.9055 - precision: 0.7560 - recall: 0.4998 - auc: 0.9179 - f1_score: 0.6009 - val_loss: 1.4759 - val_accuracy: 0.8801 - val_precision: 0.6191 - val_recall: 0.4182 - val_auc: 0.8573 - val_f1_score: 0.4965
# Epoch 109/125
# 449/449 [==============================] - 63s 141ms/step - loss: 1.6467 - accuracy: 0.9053 - precision: 0.7519 - recall: 0.5027 - auc: 0.9185 - f1_score: 0.6017 - val_loss: 1.4721 - val_accuracy: 0.8808 - val_precision: 0.6210 - val_recall: 0.4248 - val_auc: 0.8593 - val_f1_score: 0.5060
#
# Epoch 00109: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 00109: early stopping

# %% [markdown]
# # 6. Evaluate Model

# %% [markdown]
# ## 6.1 Check some Score

# %%
#  Som Scores of train & test set

train_evalation = model.evaluate(train_dataset)
test_evaluation = model.evaluate(test_dataset)
# Out:
# 449/449 [==============================] - 55s 122ms/step - loss: 0.9942 - accuracy: 0.9157 - precision: 0.8044 - recall: 0.5414 - auc: 0.9378 - f1_score: 0.6460
# 113/113 [==============================] - 7s 63ms/step - loss: 1.4721 - accuracy: 0.8808 - precision: 0.6210 - recall: 0.4248 - auc: 0.8593 - f1_score: 0.5016

# %%
metric_list = ["Loss","Accuracy", "Precision", "Recall", "Auc", "F1_Score"]

df = pd.DataFrame(list(zip(metric_list, 
                           [round(num, 3) for num in train_evalation], 
                           [round(num, 3) for num in test_evaluation])),
                  columns=['Metric Name', 'Train', 'Validate'])

print('\n\nModel Scores\n')

HTML(df.to_html(escape=False))
# Out:
# Model Scores
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Metric Name</th>
#       <th>Train</th>
#       <th>Validate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Loss</td>
#       <td>0.994</td>
#       <td>1.472</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Accuracy</td>
#       <td>0.916</td>
#       <td>0.881</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Precision</td>
#       <td>0.804</td>
#       <td>0.621</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Recall</td>
#       <td>0.541</td>
#       <td>0.425</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Auc</td>
#       <td>0.938</td>
#       <td>0.859</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>F1_Score</td>
#       <td>0.646</td>
#       <td>0.502</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 6.2 Visualize results

# %%
hs=history.history

acc = hs['accuracy']
val_acc = hs['val_accuracy']
loss =  hs['loss']
val_loss = hs['val_loss']
auc =  hs['auc']
val_auc = hs['val_auc']
precision =hs['precision']
val_precision =hs['val_precision']
f1 = hs['f1_score']
val_f1 = hs['val_f1_score']              

plt.style.use('Solarize_Light2')

fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

ax1.plot(range(1, len(acc) + 1), acc)
ax1.plot(range(1, len(val_acc) + 1), val_acc)
ax1.set_title('History of Accuracy')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Accuracy')
ax1.legend(['training', 'validation'])


ax2.plot(range(1, len(loss) + 1), loss)
ax2.plot(range(1, len(val_loss) + 1), val_loss)
ax2.set_title('History of Loss')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Loss')
ax2.legend(['training', 'validation'])

ax3.plot(range(1, len(auc) + 1), auc)
ax3.plot(range(1, len(val_auc) + 1), val_auc)
ax3.set_title('History of AUC')
ax3.set_xlabel('Epochs')
ax3.set_ylabel('AUC')
ax3.legend(['training', 'validation'])

ax4.plot(range(1, len(precision) + 1), precision)
ax4.plot(range(1, len(val_precision) + 1), val_precision)
ax4.set_title('History of Precision')
ax4.set_xlabel('Epochs')
ax4.set_ylabel('Precision')
ax4.legend(['training', 'validation'])

ax5.plot(range(1, len(f1) + 1), f1)
ax5.plot(range(1, len(val_f1) + 1), val_f1)
ax5.set_title('History of F1-score')
ax5.set_xlabel('Epochs')
ax5.set_ylabel('F1 score')
ax5.legend(['training', 'validation'])

plt.show()

# %% [markdown]
# ## 6.3 Confusion Matrix

# %%
y_true = test_dataset.classes
y_pred =  model.predict(test_dataset)
y_pred= tf.argmax(y_pred, axis = 1).numpy()

cm = confusion_matrix(y_true = y_true, y_pred = y_pred)

# %%
plt.rcParams['figure.figsize'] = (14,7)

plt.style.use('seaborn-darkgrid')
plt.imshow(cm, interpolation='nearest', cmap='Reds')
plt.title('Confusion matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)    

print('Confusion matrix, without normalization\n')   
print(cm)

print("\n\n")
thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j],
        horizontalalignment="center",
        color="white" if cm[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# Confusion matrix, without normalization
#
# [[144  23 123 211 213 131 113]
#  [ 17   0  12  28  30  13  11]
#  [149  32 108 230 225 147 133]
#  [233  31 207 385 447 249 222]
#  [188  31 126 260 272 173 183]
#  [196  30 133 263 264 179 182]
#  [126  23 103 168 168 104 139]]

# %%
plt.style.use('seaborn')

cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(12,6))

im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)

ax.set(xticks=np.arange(cm.shape[1]),
       yticks=np.arange(cm.shape[0]),
       xticklabels=classes, yticklabels=classes,
       title = 'Normalized confusion matrix',
       ylabel='True label',
       xlabel='Predicted label')

plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")


fmt = '.2f' 
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], fmt),
                ha="center", va="center",
                color="white" if cm[i, j] > thresh else "black")

fig.tight_layout()
plt.show()

# %% [markdown]
# # 7. Save Model

# %%
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
plt.style.use('grayscale')
plt.grid(visible=None)
img_path='../input/fer2013/test/sad/PrivateTest_10702106.jpg'
test_image=image.load_img(img_path,target_size= IMAGE_SIZE,color_mode='grayscale')
test_image=image.img_to_array(test_image)
print(test_image.shape)
plt.imshow(test_image)
plt.show()

10702106
# Out:
# (48, 48, 1)
# 10702106

# %% [markdown]
# # 8. Test/Predict

# %%
img=image.load_img(img_path,target_size=IMAGE_SIZE)
img = np.expand_dims(img, axis=0)
print(img.shape)
# Out:
# (1, 48, 48, 3)

# %%
result=model.predict(img)
print(result[0])
y_pred=np.argmax(result[0])
print('The person facial emotion is:',classes[y_pred])
# Out:
# [2.1771491e-02 4.6892688e-05 1.9473286e-01 6.2871221e-03 1.2843494e-01
#  6.0734838e-01 4.1378275e-02]
# The person facial emotion is: Sad
